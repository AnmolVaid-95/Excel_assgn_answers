# %% [markdown]
# Fill in the table of 2016 sales by month by store using only 1 SUMIFS Formula (Many Sales Sample Data)

# %% [markdown]
# Using the formula as below, we can fill the table.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Drag the formula to the other cells and fill the table.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Fill in the table of 2016 sales by month by store using only 1 SUMPRODUCT Formula (Many Sales Sample Data)

# %% [markdown]
# Using the below formula and dragging the formula to all the cells we can fill the table.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Create a Pivot Table that only shoes the 2016 sales by month by store. (Many Sales Sample Data)

# %% [markdown]
# Select the Pivot Table option under Insert. After selecting the range of cells, a pivot field list option opens up. We select the columns we want to include.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We need to group the sales month wise. Select on the date and choose group selection. Enter the start date and end date as 01/01/2016 and 01/01/2017, respectively.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
