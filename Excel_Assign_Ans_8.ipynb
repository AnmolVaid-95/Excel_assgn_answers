# %% [markdown]
# The Challenge before you is to write a formula to clean the data. If you perform any mathematical operation on the data, it will return #VALUE error. You need to clean the data through a formula.
#
# We need to extract the first and last char, convert through UNICODE to know the code and replace it through UNICHAR. Extract the first and last character and replace it with blanks:
#
# =--SUBSTITUTE(SUBSTITUTE(A2,LEFT(A2,1),""),RIGHT(A2,1),"")

# %% [markdown]
# ![image.png](attachment:image.png)
