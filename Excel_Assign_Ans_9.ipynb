# %% [markdown]
# 1. Find the maximum and minimum and sum of all the radiation amounts.
#
# Using the range of values in ell A2 to A41, using the below formulas, we can find:
#
# Maximum radiation amount = MAX(A2:A41) = 188
#
# Minimum radiation amount = MIN(A2:A41) = 114
#
# Sum = SUM(A2:A41) = 5966

# %% [markdown]
# 2.      Find the count and Rank
#
# Using the count and rank formulas
#
# COUNT = COUNT(A2:A41)
#
# RANK.AVG(A2:A41)
#
# Rank.AVG returns the rank of a number in a list of numbers: its size relative to other values in the list; if more than one value has the same rank, the average rank is returned.

# %% [markdown]
# 3.      Compute the mean and standard deviation of the radiation amounts.
#
# Mean_radiation_amount = AVG(A2:A41) = 149.15
#
# Std_dev = =STDEV.S(A2:A41) = 14.98469

# %% [markdown]
# 4.      Describe a certain objective a researcher might have had in mind when collecting this data.
#
# One scenario could be to decide on the radiation dose to be given to treat cancer patients.

# %% [markdown]
# ![image.png](attachment:image.png)
