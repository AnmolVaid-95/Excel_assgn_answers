# %% [markdown]
# Write a formula which returns "Palindrome" or "Not Palindrome" for a given word in the table below:

# %% [markdown]
# For cell B4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# =IF(SUMPRODUCT(--(MID(SUBSTITUTE(B4," ",""),ROW(INDIRECT("1:"&LEN(SUBSTITUTE(B4," ","")))),1)=MID(SUBSTITUTE(B4," ",""),LEN(SUBSTITUTE(B4," ",""))+1-ROW(INDIRECT("1:"&LEN(SUBSTITUTE(B4," ","")))),1)))=LEN(SUBSTITUTE(B4," ","")),"Palindrome","Not Palindrome")

# %% [markdown]
# Drag the formula below to the other cells.

# %% [markdown]
# ![image.png](attachment:image.png)
